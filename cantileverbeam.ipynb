# %% [markdown]
# <a href="https://colab.research.google.com/github/husthorng/hello-world/blob/main/cantileverbeam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.engineeringtoolbox.com/cantilever-beams-d_1848.html

# %% [markdown]
# https://www.rainhamsteel.co.uk/products/universal-beams

# %% [markdown]
# https://mechanicalc.com/reference/beam-analysis

# %% [markdown]
# ![cantilever.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
F=3000
L=5000
E=2*10**5
I=81958913.70

# %%
h=(F*L**3/(3*E*I))
print(h)
# Out:
# 7.625772131237996

# %%
Ymax=307.2/2
Smax=Ymax*F*L/I
print(Smax)
# Out:
# 28.111646384595748
